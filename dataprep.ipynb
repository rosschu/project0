# %% [markdown]
# # Preparing Text Data Files

# %% [markdown]
# #### Parses HTML file to export structured data on postings

# %%
# Exports posts.csv
# !python3 dataprep/parse.py
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
# ...

# %% [markdown]
# #### Scrape full post content & comments from URLS

# %%
# # Navigate to scrapy project & designate file containing post links
# os.chdir(f"{CODE}/scrape_referrals")
# input_file=f"{CLEAN}/posts.csv"

# # Scrape comments
# name='comments'
# !scrapy crawl {name} -a csv_filename="{input_file}" -O "{CLEAN}/{name}.csv"

# # Scrape full content of posts
# name='posts_fulltext'
# !scrapy crawl {name} -a csv_filename="{input_file}" -O "{CLEAN}/{name}.csv"

# # Change directory back to code
# os.chdir(f"{CODE}")

# %% [markdown]
# #### Filtering out referral requests and defining basic features

# %%
# Exports posts_basic.csv
# !python3 dataprep/basic.py
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
# ...

# %% [markdown]
# #### Tokenize input text and add mask tokens to replace factual content

# %%
# Exports posts_mask.csv
# !python3 dataprep/mask_tokens.py
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
# ...

# %% [markdown]
# #### Defines linguistic features for analysis

# %%
# Exports posts_linguistic.csv
# !python3 dataprep/linguistic.py
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1755 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
#    0.00%                                          |        0 /     1754 |
# ...
